# %%
import deeplenstronomy.deeplenstronomy as dl
import matplotlib.pyplot as plt
from deeplenstronomy.visualize import view_image, view_image_rgb
from matplotlib import pyplot
pyplot.style.use('dark_background')

# %%
from deeplenstronomy import surveys
[x for x in dir(surveys) if not x.startswith('__')]
# Out:
# ['delve', 'des', 'euclid', 'hst', 'lsst', 'ztf']

# %%
dataset_AlexC = dl.make_dataset('data/AlexC_SBI_Lenses.yaml',verbose=True)
# Out:
# Entering main organization loop
# Organizing CONFIGURATION_1
# Generating images for CONFIGURATION_1
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 0 S

# %%
fig,ax=plt.subplots(10,10,figsize=(25,25))

for i in range(10):
    for j in range(10):
        ax[i,j].imshow(dataset_AlexC.CONFIGURATION_1_images[i*10+j,0])
        ax[i,j].axis('off')

plt.show()

# %%
dataset_Park = dl.make_dataset('data/Lenses_Park2021.yaml',verbose=True)

# %%
dataset_Park
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 dataset_Park
#
# NameError: name 'dataset_Park' is not defined

# %%
dataset_Park_source = dl.make_dataset('data/Lenses_Park2021_alternative.yaml',verbose=True)
# Out:
# Entering main organization loop
# Organizing CONFIGURATION_1
# Generating images for CONFIGURATION_1
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 0 S

# %%
fig,ax=plt.subplots(10,10,figsize=(25,25))

for i in range(10):
    for j in range(10):
        ax[i,j].imshow(dataset_Park_source.CONFIGURATION_1_images[i*10+j,0])
        ax[i,j].axis('off')

plt.show()

# %%
dataset_AlexC.CONFIGURATION_1_images.shape
# Out:
# (99, 1, 32, 32)

# %%
view_image(dataset_AlexC.CONFIGURATION_1_images[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 view_image(dataset_AlexC.CONFIGURATION_1_images[0])
#
# File /usr/local/Caskroom/miniforge/base/envs/env_Fermilab/lib/python3.9/site-packages/deeplenstronomy/visualize.py:24, in view_image(image, stretch_func, **imshow_kwargs)
#      22 fig, axs = plt.subplots(1, np.shape(image)[0])
#      23 for index, single_band_image in enumerate(image):
# ---> 24     axs[index].imshow(stretch_func(single_band_image), **imshow_kwargs)
#      25     axs[index].set_xticks([], [])
#      26     axs[index].set_yticks([], [])
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
dataset_AlexC.CONFIGURATION_1_images.shape

# %%
print(dataset_AlexC.configurations)
# Out:
# ['CONFIGURATION_1']

# %%
dataset_AlexC.CONFIGURATION_1_images.shape
# Out:
# (99, 1, 32, 32)

# %%
plt.imshow(dataset_AlexC.CONFIGURATION_1_images[2,0])
